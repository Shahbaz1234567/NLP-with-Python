# %% [markdown]
# # Fuzzywuzzy:
#
# 1. Python Library used for approximate string matching
#
# 2. Comparing strings & determining how similar or close to each
# other,even when ther are not an exact match

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
diseases=['Heart Attack','Brain tumor','Lung Cancer','Fever','Throat infection']
diseases
# Out:
# ['Heart Attack', 'Brain tumor', 'Lung Cancer', 'Fever', 'Throat infection']

# %%
instruments=['electrocardiograpg','Sterilizers','Defibrillators','Thermometer','ICU']

# %%
q=""" An electrocardiogram (ECG) is a medical test that detects cardiac (heart) abnormalities by
measuring the electrical activity generated by the heart as it contracts. The machine t
the patient's ECG is called an electrocardiograph
"""
q
# Out:
# " An electrocardiogram (ECG) is a medical test that detects cardiac (heart) abnormalities by\nmeasuring the electrical activity generated by the heart as it contracts. The machine t\nthe patient's ECG is called an electrocardiograph\n"

# %%
process.extract(q,diseases)
# Out:
# [('Heart Attack', 57),
#  ('Fever', 34),
#  ('Throat infection', 28),
#  ('Lung Cancer', 27),
#  ('Brain tumor', 26)]

# %%
process.extract(q,instruments)
# Out:
# [('electrocardiograpg', 56),
#  ('ICU', 38),
#  ('Thermometer', 31),
#  ('Defibrillators', 25),
#  ('Sterilizers', 17)]
