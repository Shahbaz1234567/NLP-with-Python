# %% [markdown]
# # Language model for Text completion:
#
# 1. Predict the next word or sequence of words given a context.
#
# 2. In NLP, RNN , LSTM, Transformers based model used to build

# %% [markdown]
# # Steps:
#
# 1. Data Preparation
#
# 2. Tokenization
#
# 3. Create input Sequences and Targets
#
# 4. Word Embeddings
#
# 5. Build models with RNN/LSTM/transformer based architectureTensorflow/pytorch/keras
#
# 6. Loss Function and Optimizer
#
# 7. Training
#
# 8. Evaluation
#
# 9. Inference
#
# 10. Fine-Tuning(Optional)

# %%
#import libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
#Sample Data
text_data=["The quick brown fox jumps over the lazy dog.",'She sells seashells by the seashore']
text_data
# Out:
# ['The quick brown fox jumps over the lazy dog.',
#  'She sells seashells by the seashore']

# %%
#Tokenization
tokenizer=tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(text_data)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 14

# %%
#Create input sequences and targets
input_sequences=[]
for line in text_data:
    token_list=tokenizer.texts_to_sequences([line])[0]
    for i in range(1,len(token_list)):
        n_gram_sequence=token_list[:i+1]
        input_sequences.append(n_gram_sequence)
    
max_sequence_length=max([len(seq) for seq in input_sequences])
input_sequences=tf.keras.preprocessing.sequence.pad_sequences(input_sequences,maxlen=max_sequence_length)
x,y=input_sequences[:,:-1],input_sequences[:,-1]
y=tf.keras.utils.to_categorical(y,num_classes=total_words)

# %%
from sys import meta_path
#Build the model
model=Sequential()
model.add(Embedding(total_words,100,input_length=max_sequence_length-1)) # input embedd
model.add(LSTM(100)) #hidden layer
model.add(Dense(total_words,activation='softmax')) #output layer

#Compile the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#Train
model.fit(x,y,epochs=100,verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 13s - loss: 2.6408 - accuracy: 0.0000e+00 - 13s/epoch - 13s/step
# Epoch 2/100
# 1/1 - 0s - loss: 2.6315 - accuracy: 0.0000e+00 - 34ms/epoch - 34ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 2.6223 - accuracy: 0.0769 - 31ms/epoch - 31ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 2.6129 - accuracy: 0.3077 - 16ms/epoch - 16ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 2.6033 - accuracy: 0.3846 - 22ms/epoch - 22ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 2.5932 - accuracy: 0.3077 - 21ms/epoch - 21ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 2.5825 - accuracy: 0.3077 - 18ms/epoch - 18ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 2.5710 - accuracy: 0.3077 - 16ms/epoch - 16ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 2.5586 - accuracy: 0.3077 - 22ms/epoch - 22ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 2.5449 - accuracy: 0.3077 - 19ms/epoch - 19ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 2.5298 - accuracy: 0.2308 - 24ms/epoch - 24ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 2.5130 - accuracy: 0.2308 - 20ms/epoch - 20ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 2.4943 - accuracy: 0.2308 - 12ms/epoch - 12ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 2.4732 - accuracy: 0.2308 - 20ms/epoch - 20ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 2.4495 - accuracy: 0.2308 - 21ms/epoch - 21ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 2.4229 - accuracy: 0.2308 - 25ms/epoch - 25ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 2.3929 - accuracy: 0.2308 - 23ms/epoch - 23ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.3593 - accuracy: 0.3077 - 27ms/epoch - 27ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2.3221 - accuracy: 0.3077 - 11ms/epoch - 11ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2.2816 - accuracy: 0.3077 - 23ms/epoch - 23ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 2.2382 - accuracy: 0.3077 - 24ms/epoch - 24ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 2.1933 - accuracy: 0.3077 - 26ms/epoch - 26ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 2.1481 - accuracy: 0.3077 - 21ms/epoch - 21ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 2.1034 - accuracy: 0.3077 - 19ms/epoch - 19ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 2.0588 - accuracy: 0.3077 - 16ms/epoch - 16ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2.0128 - accuracy: 0.3077 - 15ms/epoch - 15ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 1.9636 - accuracy: 0.3077 - 19ms/epoch - 19ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 1.9110 - accuracy: 0.3846 - 18ms/epoch - 18ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 1.8565 - accuracy: 0.5385 - 24ms/epoch - 24ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 1.8021 - accuracy: 0.5385 - 16ms/epoch - 16ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 1.7497 - accuracy: 0.6154 - 19ms/epoch - 19ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 1.6997 - accuracy: 0.6154 - 16ms/epoch - 16ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 1.6519 - accuracy: 0.5385 - 18ms/epoch - 18ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1.6060 - accuracy: 0.5385 - 21ms/epoch - 21ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 1.5607 - accuracy: 0.6154 - 15ms/epoch - 15ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 1.5139 - accuracy: 0.6154 - 19ms/epoch - 19ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 1.4644 - accuracy: 0.7692 - 13ms/epoch - 13ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 1.4121 - accuracy: 0.8462 - 19ms/epoch - 19ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 1.3573 - accuracy: 0.8462 - 13ms/epoch - 13ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 1.3016 - accuracy: 0.7692 - 18ms/epoch - 18ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 1.2460 - accuracy: 0.7692 - 15ms/epoch - 15ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 1.1911 - accuracy: 0.7692 - 20ms/epoch - 20ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 1.1358 - accuracy: 0.8462 - 13ms/epoch - 13ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 1.0804 - accuracy: 0.9231 - 21ms/epoch - 21ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 1.0253 - accuracy: 0.9231 - 14ms/epoch - 14ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.9718 - accuracy: 0.9231 - 18ms/epoch - 18ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.9215 - accuracy: 0.9231 - 16ms/epoch - 16ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.8749 - accuracy: 0.9231 - 21ms/epoch - 21ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.8315 - accuracy: 0.9231 - 15ms/epoch - 15ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.7916 - accuracy: 0.9231 - 17ms/epoch - 17ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.7522 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.7128 - accuracy: 1.0000 - 22ms/epoch - 22ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.6758 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.6452 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.6183 - accuracy: 1.0000 - 20ms/epoch - 20ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.5884 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.5585 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.5336 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.5126 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.4913 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.4669 - accuracy: 1.0000 - 19ms/epoch - 19ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.4464 - accuracy: 1.0000 - 20ms/epoch - 20ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.4304 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.4136 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.3956 - accuracy: 1.0000 - 19ms/epoch - 19ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.3785 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.3650 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.3528 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.3386 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.3243 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.3117 - accuracy: 1.0000 - 20ms/epoch - 20ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.3014 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.2917 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.2805 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.2692 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.2589 - accuracy: 1.0000 - 23ms/epoch - 23ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.2503 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.2427 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.2346 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.2263 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.2176 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.2099 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.2033 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.1973 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.1916 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.1854 - accuracy: 1.0000 - 19ms/epoch - 19ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.1792 - accuracy: 1.0000 - 23ms/epoch - 23ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.1729 - accuracy: 1.0000 - 21ms/epoch - 21ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.1670 - accuracy: 1.0000 - 22ms/epoch - 22ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.1619 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.1573 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.1529 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.1484 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.1438 - accuracy: 1.0000 - 24ms/epoch - 24ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.1391 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.1347 - accuracy: 1.0000 - 19ms/epoch - 19ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.1307 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.1272 - accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.1237 - accuracy: 1.0000 - 18ms/epoch - 18ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.1202 - accuracy: 1.0000 - 19ms/epoch - 19ms/step

# %%
#Generate text completion

seed_text="she sells seashells"
next_words=10
for _ in range(next_words):
    token_list=tokenizer.texts_to_sequences([seed_text])[0]
    token_list=tf.keras.preprocessing.sequence.pad_sequences([token_list],maxlen=max_sequence_length-1)
    
    predicted=np.argmax(model.predict(token_list,verbose=2))
    output_word=""
    
    for word,index in tokenizer.word_index.items():
        if index==predicted:
            output_word=word
            break
    seed_text +=" "+output_word
print(seed_text)
# Out:
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# she sells seashells by the seashore seashore the dog dog dog dog dog

# %%
#Generate text completion

seed_text="quick brown fox"
next_words=3
for _ in range(next_words):
    token_list=tokenizer.texts_to_sequences([seed_text])[0]
    token_list=tf.keras.preprocessing.sequence.pad_sequences([token_list],maxlen=max_sequence_length-1)
    
    predicted=np.argmax(model.predict(token_list,verbose=2))
    output_word=""
    
    for word,index in tokenizer.word_index.items():
        if index==predicted:
            output_word=word
            break
    seed_text +=" "+output_word
print(seed_text)
# Out:
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - 33ms/epoch - 33ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# quick brown fox fox jumps over
